# %%
#read the listings.json file and print out schema to investigate the data structure. This file is for testing and will be deleted later.
import json

with open('../../listings.json', 'r') as file:
    data = json.load(file)

print(json.dumps(data, indent=4))
# Out:
# {
#     "properties": [
#         {
#             "advertisers": [
#                 {
#                     "office": {
#                         "name": "Appfolio",
#                         "phones": [
#                             {
#                                 "ext": null,
#                                 "number": null,
#                                 "primary": false,
#                                 "trackable": null,
#                                 "type": "office"
#                             },
#                             {
#                                 "ext": null,
#                                 "number": "3524153260",
#                                 "primary": false,
#                                 "trackable": null,
#                                 "type": "primary"
#                             }
#                         ]
#                     },
#                     "phones": null,
#                     "rental_management": null,
# ...

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['properties'])

# %%
actual_data = data['properties']

# %%
type(actual_data)
# Out:
# list

# %%
len(actual_data)
# Out:
# 150

# %%
type(actual_data[0])
# Out:
# dict

# %%
actual_data[0].keys()
# Out:
# dict_keys(['advertisers', 'application_url', 'branding', 'description', 'details', 'flags', 'has_specials', 'lead_attributes', 'list_date', 'list_price', 'list_price_max', 'list_price_min', 'listing_id', 'location', 'matterport', 'other_listings', 'permalink', 'pet_policy', 'photos', 'price_reduced_amount', 'primary_photo', 'products', 'property_id', 'search_promotions', 'source', 'status', 'units', 'virtual_tours'])

# %%
prop = actual_data[0]

# %%
list_data_model = {
    "listing_id": prop["listing_id"],
    "property_id": prop["property_id"],
    "list_price_max": prop["list_price_max"],
    "list_price_min": prop["list_price_min"],
    "Address": prop["location"]["address"]["line"],
    "Postal Code": prop["location"]["address"]["postal_code"],
    "City": prop["location"]["address"]["city"],
    "State": prop["location"]["address"]["state_code"],
    "Cats": prop["pet_policy"]["cats"],
    "Dogs": prop["pet_policy"]["dogs"],
    "Photos": [photo["href"] for photo in prop["photos"]],
    "Details": "generated by ai in the pipeline"
}
unit_details = []
for i in range(len(prop["units"])):
    unit_details_model = {
    "listing_id": prop["listing_id"],
    "property_id": prop["property_id"],
    "availability": prop["units"][i]["availability"]["date"],
    "beds": prop["units"][i]["description"]["beds"],
    "baths": prop["units"][i]["description"]["baths"],
    "sqft": prop["units"][i]["description"]["sqft"],
    "list_price": prop["units"][i]["list_price"],
    
}

# %%
list_data_model
# Out:
# {'listing_id': '2967532842',
#  'property_id': '6006866493',
#  'list_price_max': 1499,
#  'list_price_min': 1499,
#  'Address': '4125 SW 31st Dr',
#  'Postal Code': '32608',
#  'City': 'Gainesville',
#  'State': 'FL',
#  'Cats': True,
#  'Dogs': True,
#  'Photos': ['https://ar.rdcpix.com/d7f266345dae18e5764526d92e99c860c-f838257349s.jpg',
#   'https://ar.rdcpix.com/d7f266345dae18e5764526d92e99c860c-f1264963987s.jpg'],
#  'Details': 'generated by ai in the pipeline'}

# %%
prop
# Out:
# {'advertisers': [{'office': {'name': 'Appfolio',
#     'phones': [{'ext': None,
#       'number': None,
#       'primary': False,
#       'trackable': None,
#       'type': 'office'},
#      {'ext': None,
#       'number': '3524153260',
#       'primary': False,
#       'trackable': None,
#       'type': 'primary'}]},
#    'phones': None,
#    'rental_management': None,
#    'type': 'management'},
#   {'office': {'name': 'Silver Springs Apartments | 1-3 Bedroom Apartments in Gainesville, FL',
#     'phones': [{'ext': None,
#       'number': '3524153260',
#       'primary': False,
#       'trackable': None,
#       'type': 'office'}]},
#    'phones': None,
#    'rental_management': None,
#    'type': 'community'}],
#  'application_url': None,
#  'branding': [{'name': None, 'photo': None, 'type': 'Office'}],
#  'description': {'baths_consolidated': None,
#   'baths_max': 1,
#   'baths_min': 1,
#   'beds': None,
#   'beds_max': 3,
#   'beds_min': 3,
#   'garage': None,
# ...

# %%
actual_data[10]
# Out:
# {'advertisers': [{'office': {'name': 'AppfolioShowcase',
#     'phones': [{'ext': None,
#       'number': None,
#       'primary': False,
#       'trackable': None,
#       'type': 'office'},
#      {'ext': None,
#       'number': '3529001485',
#       'primary': False,
#       'trackable': None,
#       'type': 'primary'}]},
#    'phones': None,
#    'rental_management': None,
#    'type': 'management'},
#   {'office': {'name': '618 SW 68th Terrace',
#     'phones': [{'ext': '1',
#       'number': '3529001485',
#       'primary': False,
#       'trackable': None,
#       'type': 'office'}]},
#    'phones': None,
#    'rental_management': None,
#    'type': 'community'}],
#  'application_url': None,
#  'branding': [{'name': None, 'photo': None, 'type': 'Office'}],
#  'description': {'baths_consolidated': None,
#   'baths_max': 1.5,
#   'baths_min': 1.5,
#   'beds': None,
#   'beds_max': 2,
#   'beds_min': 2,
#   'garage': None,
#   'garage_max': None,
#   'garage_min': None,
# ...

# %%
for data in actual_data:
    if not data["location"]["address"]["postal_code"]:
        print(data)

# %%
{'advertisers': [{'office': {'name': 'Collier Companies', 'phones': [{'ext': None, 'number': None, 'primary': False, 'trackable': None, 'type': 'office'}, {'ext': None, 'number': '3525800014', 'primary': False, 'trackable': None, 'type': 'primary'}]}, 'phones': None, 'rental_management': None, 'type': 'management'}, {'office': {'name': 'Boardwalk', 'phones': [{'ext': None, 'number': '3525800014', 'primary': False, 'trackable': None, 'type': 'office'}]}, 'phones': None, 'rental_management': None, 'type': 'community'}], 'application_url': None, 'branding': [{'name': None, 'photo': None, 'type': 'Office'}], 'description': {'baths_consolidated': None, 'baths_max': 2, 'baths_min': 1, 'beds': None, 'beds_max': 3, 'beds_min': 1, 'garage': None, 'garage_max': None, 'garage_min': None, 'name': 'Boardwalk', 'sqft': None, 'sqft_max': 1120, 'sqft_min': 560, 'sub_type': None, 'type': 'apartment', 'year_built': 1984}, 'details': [{'category': 'Community Features', 'parent_category': 'Community', 'text': ['Barbecue Area', ' Basketball Court', ' Club House', ' Exterior Type: Conventional', ' Fitness Center', ' High-End Appliances', ' Laundry', ' Open Concept Floor Plan with Large Premier Bedroom Suites', ' Play Ground', ' Pool', ' Soccer Field', ' Two-Story Loft Living*', ' Zoned for Abraham Lincoln Middle School', ' Zoned for Eastside High School', ' Zoned for Idylwild Elementary School']}], 'flags': {'is_new_listing': False, 'is_pending': None}, 'has_specials': False, 'lead_attributes': {'is_premium_ldp': False, 'is_schedule_a_tour': True, 'lead_type': 'rental_go_direct'}, 'list_date': '2024-05-02T00:22:02.000000Z', 'list_price': None, 'list_price_max': 1736, 'list_price_min': 1175, 'listing_id': '2966871151', 'location': {'address': {'city': 'Gainesville', 'coordinate': {'lat': 29.62674, 'lon': -82.338096}, 'country': 'USA', 'line': '2701 SW 13th St', 'postal_code': '32608', 'state_code': 'FL'}, 'county': {'fips_code': '12001', 'name': 'Alachua'}}, 'matterport': True, 'other_listings': {'rdc': [{'listing_id': '2966871151', 'status': 'for_rent'}, {'listing_id': '2956103996', 'status': 'off_market'}, {'listing_id': '2952840178', 'status': 'off_market'}, {'listing_id': '599948090', 'status': 'off_market'}, {'listing_id': '636138414', 'status': 'off_market'}, {'listing_id': '604213362', 'status': 'off_market'}, {'listing_id': '592526870', 'status': 'off_market'}]}, 'permalink': '2701-SW-13th-St_Gainesville_FL_32608_M55500-64394', 'pet_policy': {'cats': False, 'dogs': False, 'dogs_large': False, 'dogs_small': False}, 'photos': [{'href': 'https://ar.rdcpix.com/d1d2feb3bddcafd1a46ecff7487854b7c-f2544145626s.jpg'}, {'href': 'https://ar.rdcpix.com/d1d2feb3bddcafd1a46ecff7487854b7c-f3943704251s.jpg'}], 'price_reduced_amount': None, 'primary_photo': {'href': 'https://ar.rdcpix.com/d1d2feb3bddcafd1a46ecff7487854b7c-f2544145626s.jpg'}, 'products': {'brand_name': 'basic_opt_in', 'products': ['co_broke', 'rentals_cost_per_lead_hybrid']}, 'property_id': '5550064394', 'search_promotions': None, 'source': {'community_id': 4383071, 'feed_type': 'Syndicator Community', 'id': 'ZILL', 'type': 'community'}, 'status': 'for_rent', 'units': [{'availability': None, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 3, 'sqft': 1120}, 'list_price': 1616}, {'availability': {'date': '2026-02-21'}, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 3, 'sqft': 1120}, 'list_price': 1566}, {'availability': {'date': '2026-02-20'}, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 2, 'sqft': 980}, 'list_price': 1485}, {'availability': {'date': '2026-03-25'}, 'description': {'baths': 1, 'baths_consolidated': None, 'beds': 1, 'sqft': 560}, 'list_price': 1175}, {'availability': None, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 2, 'sqft': 980}, 'list_price': 1395}, {'availability': None, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 2, 'sqft': 980}, 'list_price': 1485}, {'availability': {'date': '2026-04-08'}, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 3, 'sqft': 1120}, 'list_price': 1666}, {'availability': None, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 3, 'sqft': 1120}, 'list_price': 1576}, {'availability': None, 'description': {'baths': 1, 'baths_consolidated': None, 'beds': 1, 'sqft': 860}, 'list_price': 1299}, {'availability': None, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 2, 'sqft': 980}, 'list_price': 1495}, {'availability': None, 'description': {'baths': 2, 'baths_consolidated': None, 'beds': 3, 'sqft': 1120}, 'list_price': 1736}], 'virtual_tours': [{'href': 'https://www.youtube.com/embed/2oyq0mrnW5U?loop=1&modestbranding=1&rel=0'}]}
# Out:
# {'advertisers': [{'office': {'name': 'Collier Companies',
#     'phones': [{'ext': None,
#       'number': None,
#       'primary': False,
#       'trackable': None,
#       'type': 'office'},
#      {'ext': None,
#       'number': '3525800014',
#       'primary': False,
#       'trackable': None,
#       'type': 'primary'}]},
#    'phones': None,
#    'rental_management': None,
#    'type': 'management'},
#   {'office': {'name': 'Boardwalk',
#     'phones': [{'ext': None,
#       'number': '3525800014',
#       'primary': False,
#       'trackable': None,
#       'type': 'office'}]},
#    'phones': None,
#    'rental_management': None,
#    'type': 'community'}],
#  'application_url': None,
#  'branding': [{'name': None, 'photo': None, 'type': 'Office'}],
#  'description': {'baths_consolidated': None,
#   'baths_max': 2,
#   'baths_min': 1,
#   'beds': None,
#   'beds_max': 3,
#   'beds_min': 1,
#   'garage': None,
#   'garage_max': None,
#   'garage_min': None,
# ...

# %% [markdown]
# Key insight. A listing is for a complex. Includes rental data for multiple types of units

# %% [markdown]
# #### So the schema for the home can be the
# propertyId (key), redfinURL, propertyType (int)
# min beds, max beds, min baths, max baths
#
#
# issues: we cannot match a users interest in 2 bed 3 bath
